# %%
import numpy as np
import tensorflow as tf
from collections import deque
import random

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
class DQN:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()

    def _build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Dense(24, input_dim=self.state_size, activation='relu'),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dense(self.action_size, activation='linear')
        ])
        model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state, verbose=0)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.target_model.predict(next_state, verbose=0)[0])
            target_f = self.model.predict(state, verbose=0)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
class TaskSchedulerEnv:
    def __init__(self):
        self.max_deadline = 30  # Max days for a task deadline
        self.action_space = np.linspace(0.1, 1.0, 10)  # Deadline fractions (0.1 to 1.0)
        self.state_size = 2  # [urgency, student_type]
        self.action_size = len(self.action_space)
        self.reset()

    def reset(self):
        # Randomly initialize task urgency (time remaining) and student type
        self.time_remaining = np.random.randint(5, self.max_deadline + 1)
        self.student_type = np.random.choice([0, 1])  # 0: active, 1: procrastinator
        self.urgency = 1 - (self.time_remaining / self.max_deadline)  # Normalize urgency
        self.state = np.array([[self.urgency, self.student_type]])
        return self.state

    def step(self, action):
        # Action is an index selecting a deadline fraction
        deadline_fraction = self.action_space[action]
        assigned_deadline = max(1, int(self.time_remaining * deadline_fraction))

        # Simulate task completion
        if self.student_type == 1:  # Procrastinator
            # Procrastinators tend to delay, so tighter deadlines are better
            completion_time = np.random.randint(assigned_deadline, self.time_remaining + 1)
            if completion_time <= assigned_deadline:
                reward = 10  # Task completed on time
            else:
                reward = -10  # Missed assigned deadline
            # Bonus for tight deadlines for procrastinators
            reward += (1 - deadline_fraction) * 5
        else:  # Active student
            # Active students complete tasks early or on time
            completion_time = np.random.randint(1, assigned_deadline + 1)
            if completion_time <= assigned_deadline:
                reward = 10
            else:
                reward = -10
            # Penalty for unnecessarily tight deadlines
            reward -= (1 - deadline_fraction) * 5

        # Update state
        self.time_remaining = max(1, self.time_remaining - assigned_deadline)
        self.urgency = 1 - (self.time_remaining / self.max_deadline)
        next_state = np.array([[self.urgency, self.student_type]])

        # Check if task is done
        done = self.time_remaining <= 0 or completion_time > self.time_remaining

        return next_state, reward, done, {"assigned_deadline": assigned_deadline}

# %%
def train_dqn(episodes=1000):
    env = TaskSchedulerEnv()
    agent = DQN(state_size=env.state_size, action_size=env.action_size)
    batch_size = 32
    scores = []

    for e in range(episodes):
        state = env.reset()
        score = 0
        for time in range(100):  # Max steps per episode
            action = agent.act(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break
        scores.append(score)

        # Replay and update target model
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
        if e % 50 == 0:
            agent.update_target_model()

        print(f"Episode {e}/{episodes}, Score: {score}, Epsilon: {agent.epsilon:.2f}")

    return agent, scores

# %%
# Test the trained model
def test_dqn(agent, episodes=10):
    env = TaskSchedulerEnv()
    for e in range(episodes):
        state = env.reset()
        student_type = "Procrastinator" if state[0][1] == 1 else "Active"
        print(f"\nEpisode {e+1}, Student Type: {student_type}, Initial Urgency: {state[0][0]:.2f}")
        done = False
        while not done:
            action = agent.act(state)
            deadline_fraction = env.action_space[action]
            next_state, reward, done, info = env.step(action)
            print(f"Assigned Deadline: {info['assigned_deadline']} days, Reward: {reward}")
            state = next_state
            if done:
                print("Task completed or deadline passed.")

# %%
if __name__ == "__main__":
    # Train the model
    agent, scores = train_dqn(episodes=500)
    
    # Save the model
    agent.save("dqn_task_scheduler.weights.h5")
    
    # Test the model
    print("\nTesting the trained model:")
    test_dqn(agent, episodes=5)
# Out:
# c:\Users\abdal\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Episode 0/500, Score: -8.0, Epsilon: 1.00
# Episode 1/500, Score: 25.5, Epsilon: 1.00
# Episode 2/500, Score: 10.0, Epsilon: 1.00
# Episode 3/500, Score: 4.0, Epsilon: 1.00
# Episode 4/500, Score: 41.5, Epsilon: 1.00
# Episode 5/500, Score: -15.5, Epsilon: 1.00
# Episode 6/500, Score: 9.0, Epsilon: 1.00
# Episode 7/500, Score: 14.0, Epsilon: 1.00
# Episode 8/500, Score: -7.5, Epsilon: 1.00
# Episode 9/500, Score: 11.0, Epsilon: 1.00
# Episode 10/500, Score: 10.0, Epsilon: 1.00
# Episode 11/500, Score: 773.0, Epsilon: 0.99
# Episode 12/500, Score: 15.0, Epsilon: 0.99
# Episode 13/500, Score: 9.5, Epsilon: 0.99
# Episode 14/500, Score: -12.5, Epsilon: 0.98
# Episode 15/500, Score: 9.5, Epsilon: 0.98
# Episode 16/500, Score: -8.0, Epsilon: 0.97
# Episode 17/500, Score: 27.0, Epsilon: 0.97
# Episode 18/500, Score: 9.0, Epsilon: 0.96
# Episode 19/500, Score: 8.0, Epsilon: 0.96
# Episode 20/500, Score: 764.0, Epsilon: 0.95
# Episode 21/500, Score: -6.0, Epsilon: 0.95
# Episode 22/500, Score: -13.0, Epsilon: 0.94
# Episode 23/500, Score: 777.5, Epsilon: 0.94
# Episode 24/500, Score: 9.5, Epsilon: 0.93
# Episode 25/500, Score: 15.5, Epsilon: 0.93
# Episode 26/500, Score: 5.5, Epsilon: 0.92
# Episode 27/500, Score: 796.5, Epsilon: 0.92
# Episode 28/500, Score: 804.0, Epsilon: 0.91
# Episode 29/500, Score: 792.5, Epsilon: 0.91
# Episode 30/500, Score: 17.0, Epsilon: 0.90
# Episode 31/500, Score: 15.0, Epsilon: 0.90
# Episode 32/500, Score: 17.0, Epsilon: 0.90
# Episode 33/500, Score: 790.5, Epsilon: 0.89
# Episode 34/500, Score: -2.0, Epsilon: 0.89
# Episode 35/500, Score: 10.0, Epsilon: 0.88
# Episode 36/500, Score: -9.5, Epsilon: 0.88
# Episode 37/500, Score: -8.0, Epsilon: 0.87
# Episode 38/500, Score: 22.5, Epsilon: 0.87
# Episode 39/500, Score: 9.5, Epsilon: 0.86
# Episode 40/500, Score: -8.5, Epsilon: 0.86
# Episode 41/500, Score: 809.5, Epsilon: 0.86
# Episode 42/500, Score: 10.0, Epsilon: 0.85
# Episode 43/500, Score: -6.5, Epsilon: 0.85
# Episode 44/500, Score: 17.5, Epsilon: 0.84
# Episode 45/500, Score: -14.5, Epsilon: 0.84
# Episode 46/500, Score: 10.0, Epsilon: 0.83
# Episode 47/500, Score: -6.5, Epsilon: 0.83
# Episode 48/500, Score: 23.0, Epsilon: 0.83
# Episode 49/500, Score: 9.0, Epsilon: 0.82
# Episode 50/500, Score: 824.0, Epsilon: 0.82
# Episode 51/500, Score: 9.5, Epsilon: 0.81
# Episode 52/500, Score: 10.0, Epsilon: 0.81
# Episode 53/500, Score: -7.0, Epsilon: 0.81
# Episode 54/500, Score: 17.5, Epsilon: 0.80
# Episode 55/500, Score: -8.0, Epsilon: 0.80
# Episode 56/500, Score: 16.5, Epsilon: 0.79
# Episode 57/500, Score: 11.0, Epsilon: 0.79
# Episode 58/500, Score: 9.5, Epsilon: 0.79
# Episode 59/500, Score: 21.0, Epsilon: 0.78
# Episode 60/500, Score: 23.0, Epsilon: 0.78
# Episode 61/500, Score: 10.0, Epsilon: 0.77
# Episode 62/500, Score: 18.5, Epsilon: 0.77
# Episode 63/500, Score: 29.0, Epsilon: 0.77
# Episode 64/500, Score: 10.0, Epsilon: 0.76
# Episode 65/500, Score: 10.0, Epsilon: 0.76
# Episode 66/500, Score: 2.5, Epsilon: 0.76
# Episode 67/500, Score: 11.0, Epsilon: 0.75
# Episode 68/500, Score: 10.0, Epsilon: 0.75
# Episode 69/500, Score: -9.5, Epsilon: 0.74
# Episode 70/500, Score: 10.0, Epsilon: 0.74
# Episode 71/500, Score: 4.5, Epsilon: 0.74
# Episode 72/500, Score: 10.0, Epsilon: 0.73
# Episode 73/500, Score: 821.5, Epsilon: 0.73
# Episode 74/500, Score: 5.0, Epsilon: 0.73
# Episode 75/500, Score: 10.0, Epsilon: 0.72
# Episode 76/500, Score: 10.0, Epsilon: 0.72
# Episode 77/500, Score: -8.0, Epsilon: 0.71
# Episode 78/500, Score: 10.0, Epsilon: 0.71
# Episode 79/500, Score: 10.0, Epsilon: 0.71
# Episode 80/500, Score: 4.5, Epsilon: 0.70
# Episode 81/500, Score: -9.0, Epsilon: 0.70
# Episode 82/500, Score: 842.5, Epsilon: 0.70
# Episode 83/500, Score: 22.0, Epsilon: 0.69
# Episode 84/500, Score: 10.0, Epsilon: 0.69
# Episode 85/500, Score: 10.0, Epsilon: 0.69
# Episode 86/500, Score: 10.0, Epsilon: 0.68
# Episode 87/500, Score: 840.5, Epsilon: 0.68
# Episode 88/500, Score: 9.0, Epsilon: 0.68
# Episode 89/500, Score: 8.5, Epsilon: 0.67
# Episode 90/500, Score: -2.0, Epsilon: 0.67
# Episode 91/500, Score: -15.0, Epsilon: 0.67
# Episode 92/500, Score: 10.0, Epsilon: 0.66
# Episode 93/500, Score: 10.0, Epsilon: 0.66
# Episode 94/500, Score: 9.0, Epsilon: 0.66
# Episode 95/500, Score: 11.0, Epsilon: 0.65
# Episode 96/500, Score: 10.0, Epsilon: 0.65
# Episode 97/500, Score: 10.0, Epsilon: 0.65
# Episode 98/500, Score: 29.0, Epsilon: 0.64
# Episode 99/500, Score: 3.5, Epsilon: 0.64
# Episode 100/500, Score: -7.5, Epsilon: 0.64
# Episode 101/500, Score: 10.0, Epsilon: 0.63
# Episode 102/500, Score: -9.0, Epsilon: 0.63
# Episode 103/500, Score: -8.5, Epsilon: 0.63
# Episode 104/500, Score: 849.5, Epsilon: 0.62
# Episode 105/500, Score: -13.0, Epsilon: 0.62
# Episode 106/500, Score: 10.0, Epsilon: 0.62
# Episode 107/500, Score: 10.0, Epsilon: 0.61
# Episode 108/500, Score: 15.5, Epsilon: 0.61
# Episode 109/500, Score: 10.0, Epsilon: 0.61
# Episode 110/500, Score: 4.0, Epsilon: 0.61
# Episode 111/500, Score: 9.5, Epsilon: 0.60
# Episode 112/500, Score: 10.0, Epsilon: 0.60
# Episode 113/500, Score: -7.0, Epsilon: 0.60
# Episode 114/500, Score: 9.5, Epsilon: 0.59
# Episode 115/500, Score: 10.0, Epsilon: 0.59
# Episode 116/500, Score: 872.0, Epsilon: 0.59
# Episode 117/500, Score: -9.0, Epsilon: 0.58
# Episode 118/500, Score: 10.0, Epsilon: 0.58
# Episode 119/500, Score: 10.0, Epsilon: 0.58
# Episode 120/500, Score: 8.0, Epsilon: 0.58
# Episode 121/500, Score: -6.5, Epsilon: 0.57
# Episode 122/500, Score: 24.0, Epsilon: 0.57
# Episode 123/500, Score: 836.5, Epsilon: 0.57
# Episode 124/500, Score: 11.5, Epsilon: 0.56
# Episode 125/500, Score: 15.5, Epsilon: 0.56
# Episode 126/500, Score: 10.0, Epsilon: 0.56
# Episode 127/500, Score: -8.0, Epsilon: 0.56
# Episode 128/500, Score: -5.5, Epsilon: 0.55
# Episode 129/500, Score: 10.0, Epsilon: 0.55
# Episode 130/500, Score: 850.0, Epsilon: 0.55
# Episode 131/500, Score: -9.0, Epsilon: 0.55
# Episode 132/500, Score: 10.0, Epsilon: 0.54
# Episode 133/500, Score: 18.0, Epsilon: 0.54
# Episode 134/500, Score: -7.0, Epsilon: 0.54
# Episode 135/500, Score: 16.5, Epsilon: 0.53
# Episode 136/500, Score: 10.0, Epsilon: 0.53
# Episode 137/500, Score: -8.0, Epsilon: 0.53
# Episode 138/500, Score: 16.5, Epsilon: 0.53
# Episode 139/500, Score: 10.0, Epsilon: 0.52
# Episode 140/500, Score: -9.5, Epsilon: 0.52
# Episode 141/500, Score: 10.0, Epsilon: 0.52
# Episode 142/500, Score: 22.0, Epsilon: 0.52
# Episode 143/500, Score: 10.0, Epsilon: 0.51
# Episode 144/500, Score: 10.0, Epsilon: 0.51
# Episode 145/500, Score: 21.0, Epsilon: 0.51
# Episode 146/500, Score: 10.0, Epsilon: 0.51
# Episode 147/500, Score: 4.5, Epsilon: 0.50
# Episode 148/500, Score: -9.5, Epsilon: 0.50
# Episode 149/500, Score: 10.0, Epsilon: 0.50
# Episode 150/500, Score: -7.0, Epsilon: 0.50
# Episode 151/500, Score: 10.0, Epsilon: 0.49
# Episode 152/500, Score: 791.0, Epsilon: 0.49
# Episode 153/500, Score: 9.0, Epsilon: 0.49
# Episode 154/500, Score: 10.0, Epsilon: 0.49
# Episode 155/500, Score: 4.5, Epsilon: 0.48
# Episode 156/500, Score: 10.0, Epsilon: 0.48
# Episode 157/500, Score: -9.0, Epsilon: 0.48
# Episode 158/500, Score: 10.0, Epsilon: 0.48
# Episode 159/500, Score: 10.0, Epsilon: 0.47
# Episode 160/500, Score: 10.0, Epsilon: 0.47
# Episode 161/500, Score: 861.5, Epsilon: 0.47
# Episode 162/500, Score: 10.0, Epsilon: 0.47
# Episode 163/500, Score: 823.5, Epsilon: 0.46
# Episode 164/500, Score: -15.5, Epsilon: 0.46
# Episode 165/500, Score: -7.5, Epsilon: 0.46
# Episode 166/500, Score: 23.0, Epsilon: 0.46
# Episode 167/500, Score: 10.0, Epsilon: 0.46
# Episode 168/500, Score: -1.5, Epsilon: 0.45
# Episode 169/500, Score: 10.0, Epsilon: 0.45
# Episode 170/500, Score: 10.0, Epsilon: 0.45
# Episode 171/500, Score: 10.0, Epsilon: 0.45
# Episode 172/500, Score: 10.0, Epsilon: 0.44
# Episode 173/500, Score: 6.0, Epsilon: 0.44
# Episode 174/500, Score: 903.0, Epsilon: 0.44
# Episode 175/500, Score: 9.0, Epsilon: 0.44
# Episode 176/500, Score: 824.5, Epsilon: 0.44
# Episode 177/500, Score: 814.0, Epsilon: 0.43
# Episode 178/500, Score: 10.0, Epsilon: 0.43
# Episode 179/500, Score: 10.0, Epsilon: 0.43
# Episode 180/500, Score: 10.0, Epsilon: 0.43
# Episode 181/500, Score: 17.5, Epsilon: 0.42
# Episode 182/500, Score: 10.0, Epsilon: 0.42
# Episode 183/500, Score: 10.0, Epsilon: 0.42
# Episode 184/500, Score: 9.5, Epsilon: 0.42
# Episode 185/500, Score: 10.0, Epsilon: 0.42
# Episode 186/500, Score: 10.0, Epsilon: 0.41
# Episode 187/500, Score: 10.0, Epsilon: 0.41
# Episode 188/500, Score: 14.5, Epsilon: 0.41
# Episode 189/500, Score: 9.5, Epsilon: 0.41
# Episode 190/500, Score: 10.0, Epsilon: 0.41
# Episode 191/500, Score: 10.0, Epsilon: 0.40
# Episode 192/500, Score: 10.0, Epsilon: 0.40
# Episode 193/500, Score: 22.5, Epsilon: 0.40
# Episode 194/500, Score: -7.0, Epsilon: 0.40
# Episode 195/500, Score: 10.0, Epsilon: 0.40
# Episode 196/500, Score: -9.5, Epsilon: 0.39
# Episode 197/500, Score: 10.0, Epsilon: 0.39
# Episode 198/500, Score: 11.5, Epsilon: 0.39
# Episode 199/500, Score: 10.0, Epsilon: 0.39
# Episode 200/500, Score: 9.0, Epsilon: 0.39
# Episode 201/500, Score: 10.0, Epsilon: 0.38
# Episode 202/500, Score: 17.5, Epsilon: 0.38
# Episode 203/500, Score: -7.0, Epsilon: 0.38
# Episode 204/500, Score: 10.0, Epsilon: 0.38
# Episode 205/500, Score: 10.0, Epsilon: 0.38
# Episode 206/500, Score: 10.0, Epsilon: 0.37
# Episode 207/500, Score: 10.0, Epsilon: 0.37
# Episode 208/500, Score: 10.0, Epsilon: 0.37
# Episode 209/500, Score: 31.0, Epsilon: 0.37
# Episode 210/500, Score: 10.0, Epsilon: 0.37
# Episode 211/500, Score: 10.0, Epsilon: 0.37
# Episode 212/500, Score: -7.5, Epsilon: 0.36
# Episode 213/500, Score: 25.0, Epsilon: 0.36
# Episode 214/500, Score: 10.0, Epsilon: 0.36
# Episode 215/500, Score: 10.0, Epsilon: 0.36
# Episode 216/500, Score: 10.0, Epsilon: 0.36
# Episode 217/500, Score: 9.5, Epsilon: 0.35
# Episode 218/500, Score: 10.0, Epsilon: 0.35
# Episode 219/500, Score: 10.0, Epsilon: 0.35
# Episode 220/500, Score: 927.0, Epsilon: 0.35
# Episode 221/500, Score: 10.0, Epsilon: 0.35
# Episode 222/500, Score: 8.5, Epsilon: 0.35
# Episode 223/500, Score: 4.5, Epsilon: 0.34
# Episode 224/500, Score: 9.0, Epsilon: 0.34
# Episode 225/500, Score: 849.5, Epsilon: 0.34
# Episode 226/500, Score: 10.0, Epsilon: 0.34
# Episode 227/500, Score: 855.0, Epsilon: 0.34
# Episode 228/500, Score: -7.0, Epsilon: 0.34
# Episode 229/500, Score: 855.5, Epsilon: 0.33
# Episode 230/500, Score: 10.0, Epsilon: 0.33
# Episode 231/500, Score: 10.0, Epsilon: 0.33
# Episode 232/500, Score: 10.0, Epsilon: 0.33
# Episode 233/500, Score: 15.5, Epsilon: 0.33
# Episode 234/500, Score: 9.0, Epsilon: 0.33
# Episode 235/500, Score: 17.0, Epsilon: 0.32
# Episode 236/500, Score: 10.0, Epsilon: 0.32
# Episode 237/500, Score: 9.0, Epsilon: 0.32
# Episode 238/500, Score: 17.0, Epsilon: 0.32
# Episode 239/500, Score: 10.0, Epsilon: 0.32
# Episode 240/500, Score: 3.5, Epsilon: 0.32
# Episode 241/500, Score: 10.0, Epsilon: 0.31
# Episode 242/500, Score: 10.0, Epsilon: 0.31
# Episode 243/500, Score: -9.0, Epsilon: 0.31
# Episode 244/500, Score: 10.0, Epsilon: 0.31
# Episode 245/500, Score: 9.5, Epsilon: 0.31
# Episode 246/500, Score: 8.0, Epsilon: 0.31
# Episode 247/500, Score: 10.0, Epsilon: 0.30
# Episode 248/500, Score: 10.0, Epsilon: 0.30
# Episode 249/500, Score: 10.0, Epsilon: 0.30
# Episode 250/500, Score: 10.0, Epsilon: 0.30
# Episode 251/500, Score: 10.0, Epsilon: 0.30
# Episode 252/500, Score: 10.0, Epsilon: 0.30
# Episode 253/500, Score: 10.0, Epsilon: 0.30
# Episode 254/500, Score: 10.0, Epsilon: 0.29
# Episode 255/500, Score: 18.0, Epsilon: 0.29
# Episode 256/500, Score: 10.0, Epsilon: 0.29
# Episode 257/500, Score: 10.0, Epsilon: 0.29
# Episode 258/500, Score: 756.5, Epsilon: 0.29
# Episode 259/500, Score: 10.0, Epsilon: 0.29
# Episode 260/500, Score: 26.0, Epsilon: 0.29
# Episode 261/500, Score: 10.0, Epsilon: 0.28
# Episode 262/500, Score: 10.0, Epsilon: 0.28
# Episode 263/500, Score: -9.5, Epsilon: 0.28
# Episode 264/500, Score: 18.0, Epsilon: 0.28
# Episode 265/500, Score: 10.0, Epsilon: 0.28
# Episode 266/500, Score: 10.0, Epsilon: 0.28
# Episode 267/500, Score: 10.0, Epsilon: 0.28
# Episode 268/500, Score: 17.0, Epsilon: 0.27
# Episode 269/500, Score: 773.0, Epsilon: 0.27
# Episode 270/500, Score: 10.0, Epsilon: 0.27
# Episode 271/500, Score: 10.0, Epsilon: 0.27
# Episode 272/500, Score: 10.0, Epsilon: 0.27
# Episode 273/500, Score: 10.0, Epsilon: 0.27
# Episode 274/500, Score: 10.0, Epsilon: 0.27
# Episode 275/500, Score: 10.0, Epsilon: 0.26
# Episode 276/500, Score: 18.5, Epsilon: 0.26
# Episode 277/500, Score: 904.5, Epsilon: 0.26
# Episode 278/500, Score: 4.0, Epsilon: 0.26
# Episode 279/500, Score: 9.0, Epsilon: 0.26
# Episode 280/500, Score: 10.0, Epsilon: 0.26
# Episode 281/500, Score: 19.0, Epsilon: 0.26
# Episode 282/500, Score: 10.0, Epsilon: 0.26
# Episode 283/500, Score: -9.5, Epsilon: 0.25
# Episode 284/500, Score: 10.0, Epsilon: 0.25
# Episode 285/500, Score: 10.0, Epsilon: 0.25
# Episode 286/500, Score: 10.0, Epsilon: 0.25
# Episode 287/500, Score: 10.0, Epsilon: 0.25
# Episode 288/500, Score: 10.0, Epsilon: 0.25
# Episode 289/500, Score: 10.0, Epsilon: 0.25
# Episode 290/500, Score: 10.0, Epsilon: 0.25
# Episode 291/500, Score: -5.5, Epsilon: 0.24
# Episode 292/500, Score: 10.0, Epsilon: 0.24
# Episode 293/500, Score: 10.0, Epsilon: 0.24
# Episode 294/500, Score: 9.0, Epsilon: 0.24
# Episode 295/500, Score: 9.5, Epsilon: 0.24
# Episode 296/500, Score: 17.5, Epsilon: 0.24
# Episode 297/500, Score: 10.0, Epsilon: 0.24
# Episode 298/500, Score: 10.0, Epsilon: 0.24
# Episode 299/500, Score: 10.0, Epsilon: 0.23
# Episode 300/500, Score: 10.0, Epsilon: 0.23
# Episode 301/500, Score: 10.0, Epsilon: 0.23
# Episode 302/500, Score: 712.0, Epsilon: 0.23
# Episode 303/500, Score: -9.5, Epsilon: 0.23
# Episode 304/500, Score: 10.0, Epsilon: 0.23
# Episode 305/500, Score: 10.0, Epsilon: 0.23
# Episode 306/500, Score: 10.0, Epsilon: 0.23
# Episode 307/500, Score: 748.5, Epsilon: 0.23
# Episode 308/500, Score: 794.0, Epsilon: 0.22
# Episode 309/500, Score: -8.0, Epsilon: 0.22
# Episode 310/500, Score: 10.0, Epsilon: 0.22
# Episode 311/500, Score: 10.0, Epsilon: 0.22
# Episode 312/500, Score: 10.0, Epsilon: 0.22
# Episode 313/500, Score: -7.5, Epsilon: 0.22
# Episode 314/500, Score: 10.0, Epsilon: 0.22
# Episode 315/500, Score: 10.0, Epsilon: 0.22
# Episode 316/500, Score: -6.0, Epsilon: 0.22
# Episode 317/500, Score: 790.0, Epsilon: 0.21
# Episode 318/500, Score: 10.0, Epsilon: 0.21
# Episode 319/500, Score: 10.0, Epsilon: 0.21
# Episode 320/500, Score: 10.0, Epsilon: 0.21
# Episode 321/500, Score: 744.5, Epsilon: 0.21
# Episode 322/500, Score: 10.0, Epsilon: 0.21
# Episode 323/500, Score: 9.5, Epsilon: 0.21
# Episode 324/500, Score: 11.0, Epsilon: 0.21
# Episode 325/500, Score: 10.0, Epsilon: 0.21
# Episode 326/500, Score: 16.5, Epsilon: 0.21
# Episode 327/500, Score: 10.0, Epsilon: 0.20
# Episode 328/500, Score: -8.0, Epsilon: 0.20
# Episode 329/500, Score: 10.0, Epsilon: 0.20
# Episode 330/500, Score: 10.0, Epsilon: 0.20
# Episode 331/500, Score: 18.0, Epsilon: 0.20
# Episode 332/500, Score: 10.0, Epsilon: 0.20
# Episode 333/500, Score: 10.0, Epsilon: 0.20
# Episode 334/500, Score: 16.0, Epsilon: 0.20
# Episode 335/500, Score: 8.0, Epsilon: 0.20
# Episode 336/500, Score: 10.0, Epsilon: 0.20
# Episode 337/500, Score: 10.0, Epsilon: 0.19
# Episode 338/500, Score: 10.0, Epsilon: 0.19
# Episode 339/500, Score: 10.0, Epsilon: 0.19
# Episode 340/500, Score: 10.0, Epsilon: 0.19
# Episode 341/500, Score: 10.0, Epsilon: 0.19
# Episode 342/500, Score: 10.0, Epsilon: 0.19
# Episode 343/500, Score: 10.0, Epsilon: 0.19
# Episode 344/500, Score: 10.0, Epsilon: 0.19
# Episode 345/500, Score: 10.0, Epsilon: 0.19
# Episode 346/500, Score: 10.0, Epsilon: 0.19
# Episode 347/500, Score: 10.0, Epsilon: 0.18
# Episode 348/500, Score: 10.0, Epsilon: 0.18
# Episode 349/500, Score: 9.0, Epsilon: 0.18
# Episode 350/500, Score: 9.0, Epsilon: 0.18
# Episode 351/500, Score: 10.0, Epsilon: 0.18
# Episode 352/500, Score: -7.5, Epsilon: 0.18
# Episode 353/500, Score: 10.0, Epsilon: 0.18
# Episode 354/500, Score: 9.0, Epsilon: 0.18
# Episode 355/500, Score: 9.0, Epsilon: 0.18
# Episode 356/500, Score: 880.5, Epsilon: 0.18
# Episode 357/500, Score: 10.0, Epsilon: 0.18
# Episode 358/500, Score: 10.0, Epsilon: 0.17
# Episode 359/500, Score: 15.5, Epsilon: 0.17
# Episode 360/500, Score: 903.0, Epsilon: 0.17
# Episode 361/500, Score: 4.5, Epsilon: 0.17
# Episode 362/500, Score: 10.0, Epsilon: 0.17
# Episode 363/500, Score: 9.0, Epsilon: 0.17
# Episode 364/500, Score: 18.0, Epsilon: 0.17
# Episode 365/500, Score: 10.0, Epsilon: 0.17
# Episode 366/500, Score: 10.0, Epsilon: 0.17
# Episode 367/500, Score: 836.0, Epsilon: 0.17
# Episode 368/500, Score: 9.0, Epsilon: 0.17
# Episode 369/500, Score: 9.5, Epsilon: 0.17
# Episode 370/500, Score: 8.5, Epsilon: 0.16
# Episode 371/500, Score: 10.0, Epsilon: 0.16
# Episode 372/500, Score: -9.0, Epsilon: 0.16
# Episode 373/500, Score: 10.0, Epsilon: 0.16
# Episode 374/500, Score: 9.0, Epsilon: 0.16
# Episode 375/500, Score: 758.5, Epsilon: 0.16
# Episode 376/500, Score: 830.0, Epsilon: 0.16
# Episode 377/500, Score: 17.5, Epsilon: 0.16
# Episode 378/500, Score: 17.0, Epsilon: 0.16
# Episode 379/500, Score: 9.0, Epsilon: 0.16
# Episode 380/500, Score: 10.0, Epsilon: 0.16
# Episode 381/500, Score: 10.0, Epsilon: 0.16
# Episode 382/500, Score: 17.0, Epsilon: 0.15
# Episode 383/500, Score: 8.0, Epsilon: 0.15
# Episode 384/500, Score: 10.0, Epsilon: 0.15
# Episode 385/500, Score: 10.0, Epsilon: 0.15
# Episode 386/500, Score: 10.0, Epsilon: 0.15
# Episode 387/500, Score: 18.0, Epsilon: 0.15
# Episode 388/500, Score: 10.0, Epsilon: 0.15
# Episode 389/500, Score: 915.5, Epsilon: 0.15
# Episode 390/500, Score: 9.0, Epsilon: 0.15
# Episode 391/500, Score: 879.5, Epsilon: 0.15
# Episode 392/500, Score: 10.0, Epsilon: 0.15
# Episode 393/500, Score: 4.0, Epsilon: 0.15
# Episode 394/500, Score: 10.0, Epsilon: 0.15
# Episode 395/500, Score: 9.0, Epsilon: 0.15
# Episode 396/500, Score: 9.0, Epsilon: 0.14
# Episode 397/500, Score: 10.0, Epsilon: 0.14
# Episode 398/500, Score: 10.0, Epsilon: 0.14
# Episode 399/500, Score: 9.0, Epsilon: 0.14
# Episode 400/500, Score: 24.5, Epsilon: 0.14
# Episode 401/500, Score: 10.0, Epsilon: 0.14
# Episode 402/500, Score: 3.0, Epsilon: 0.14
# Episode 403/500, Score: 10.0, Epsilon: 0.14
# Episode 404/500, Score: 10.0, Epsilon: 0.14
# Episode 405/500, Score: 10.0, Epsilon: 0.14
# Episode 406/500, Score: 10.0, Epsilon: 0.14
# Episode 407/500, Score: -6.0, Epsilon: 0.14
# Episode 408/500, Score: 10.0, Epsilon: 0.14
# Episode 409/500, Score: 10.0, Epsilon: 0.14
# Episode 410/500, Score: 753.0, Epsilon: 0.13
# Episode 411/500, Score: 10.0, Epsilon: 0.13
# Episode 412/500, Score: 921.5, Epsilon: 0.13
# Episode 413/500, Score: 10.0, Epsilon: 0.13
# Episode 414/500, Score: 10.0, Epsilon: 0.13
# Episode 415/500, Score: 23.0, Epsilon: 0.13
# Episode 416/500, Score: 10.0, Epsilon: 0.13
# Episode 417/500, Score: 10.0, Epsilon: 0.13
# Episode 418/500, Score: 9.0, Epsilon: 0.13
# Episode 419/500, Score: 664.0, Epsilon: 0.13
# Episode 420/500, Score: 3.0, Epsilon: 0.13
# Episode 421/500, Score: 15.0, Epsilon: 0.13
# Episode 422/500, Score: 9.0, Epsilon: 0.13
# Episode 423/500, Score: 9.0, Epsilon: 0.13
# Episode 424/500, Score: 753.0, Epsilon: 0.13
# Episode 425/500, Score: 10.0, Epsilon: 0.12
# Episode 426/500, Score: 10.0, Epsilon: 0.12
# Episode 427/500, Score: -8.0, Epsilon: 0.12
# Episode 428/500, Score: -8.0, Epsilon: 0.12
# Episode 429/500, Score: 9.0, Epsilon: 0.12
# Episode 430/500, Score: 10.0, Epsilon: 0.12
# Episode 431/500, Score: 10.0, Epsilon: 0.12
# Episode 432/500, Score: 10.0, Epsilon: 0.12
# Episode 433/500, Score: 10.0, Epsilon: 0.12
# Episode 434/500, Score: 10.0, Epsilon: 0.12
# Episode 435/500, Score: 10.0, Epsilon: 0.12
# Episode 436/500, Score: 18.5, Epsilon: 0.12
# Episode 437/500, Score: 10.0, Epsilon: 0.12
# Episode 438/500, Score: 10.0, Epsilon: 0.12
# Episode 439/500, Score: 8.0, Epsilon: 0.12
# Episode 440/500, Score: 10.0, Epsilon: 0.12
# Episode 441/500, Score: 4.5, Epsilon: 0.12
# Episode 442/500, Score: 10.0, Epsilon: 0.11
# Episode 443/500, Score: 747.5, Epsilon: 0.11
# Episode 444/500, Score: 28.5, Epsilon: 0.11
# Episode 445/500, Score: 16.0, Epsilon: 0.11
# Episode 446/500, Score: 10.0, Epsilon: 0.11
# Episode 447/500, Score: 8.0, Epsilon: 0.11
# Episode 448/500, Score: 881.0, Epsilon: 0.11
# Episode 449/500, Score: 796.5, Epsilon: 0.11
# Episode 450/500, Score: 25.5, Epsilon: 0.11
# Episode 451/500, Score: 839.5, Epsilon: 0.11
# Episode 452/500, Score: 10.0, Epsilon: 0.11
# Episode 453/500, Score: 794.0, Epsilon: 0.11
# Episode 454/500, Score: 10.0, Epsilon: 0.11
# Episode 455/500, Score: 840.5, Epsilon: 0.11
# Episode 456/500, Score: 3.5, Epsilon: 0.11
# Episode 457/500, Score: 753.5, Epsilon: 0.11
# Episode 458/500, Score: 10.0, Epsilon: 0.11
# Episode 459/500, Score: 746.5, Epsilon: 0.11
# Episode 460/500, Score: 10.0, Epsilon: 0.10
# Episode 461/500, Score: 933.5, Epsilon: 0.10
# Episode 462/500, Score: 10.0, Epsilon: 0.10
# Episode 463/500, Score: 17.0, Epsilon: 0.10
# Episode 464/500, Score: 10.0, Epsilon: 0.10
# Episode 465/500, Score: 17.5, Epsilon: 0.10
# Episode 466/500, Score: 10.0, Epsilon: 0.10
# Episode 467/500, Score: 14.0, Epsilon: 0.10
# Episode 468/500, Score: 10.0, Epsilon: 0.10
# Episode 469/500, Score: 10.0, Epsilon: 0.10
# Episode 470/500, Score: 10.0, Epsilon: 0.10
# Episode 471/500, Score: 10.0, Epsilon: 0.10
# Episode 472/500, Score: 10.0, Epsilon: 0.10
# Episode 473/500, Score: 10.0, Epsilon: 0.10
# Episode 474/500, Score: 9.0, Epsilon: 0.10
# Episode 475/500, Score: 9.0, Epsilon: 0.10
# Episode 476/500, Score: 18.0, Epsilon: 0.10
# Episode 477/500, Score: 9.0, Epsilon: 0.10
# Episode 478/500, Score: 895.5, Epsilon: 0.10
# Episode 479/500, Score: 9.0, Epsilon: 0.10
# Episode 480/500, Score: 10.0, Epsilon: 0.09
# Episode 481/500, Score: 10.0, Epsilon: 0.09
# Episode 482/500, Score: 10.0, Epsilon: 0.09
# Episode 483/500, Score: 18.5, Epsilon: 0.09
# Episode 484/500, Score: 10.0, Epsilon: 0.09
# Episode 485/500, Score: 8.0, Epsilon: 0.09
# Episode 486/500, Score: 10.0, Epsilon: 0.09
# Episode 487/500, Score: 847.5, Epsilon: 0.09
# Episode 488/500, Score: 8.5, Epsilon: 0.09
# Episode 489/500, Score: 842.5, Epsilon: 0.09
# Episode 490/500, Score: 10.0, Epsilon: 0.09
# Episode 491/500, Score: 10.0, Epsilon: 0.09
# Episode 492/500, Score: 10.0, Epsilon: 0.09
# Episode 493/500, Score: 17.0, Epsilon: 0.09
# Episode 494/500, Score: 10.0, Epsilon: 0.09
# Episode 495/500, Score: 764.0, Epsilon: 0.09
# Episode 496/500, Score: 930.5, Epsilon: 0.09
# Episode 497/500, Score: 751.5, Epsilon: 0.09
# Episode 498/500, Score: 750.0, Epsilon: 0.09
# Episode 499/500, Score: 844.5, Epsilon: 0.09
#
# Testing the trained model:
#
# Episode 1, Student Type: Procrastinator, Initial Urgency: 0.70
# Assigned Deadline: 9 days, Reward: 10.0
# Task completed or deadline passed.
#
# Episode 2, Student Type: Procrastinator, Initial Urgency: 0.43
# Assigned Deadline: 17 days, Reward: 10.0
# Task completed or deadline passed.
#
# Episode 3, Student Type: Procrastinator, Initial Urgency: 0.37
# Assigned Deadline: 19 days, Reward: 10.0
# Task completed or deadline passed.
#
# Episode 4, Student Type: Procrastinator, Initial Urgency: 0.23
# Assigned Deadline: 23 days, Reward: 10.0
# Task completed or deadline passed.
#
# Episode 5, Student Type: Procrastinator, Initial Urgency: 0.57
# Assigned Deadline: 13 days, Reward: 10.0
# Task completed or deadline passed.
